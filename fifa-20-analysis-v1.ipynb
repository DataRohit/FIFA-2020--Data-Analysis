# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
fifa = pd.read_csv("/content/drive/MyDrive/FIFA-20/fifa-20.csv")
fifa.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
#
# [5 rows x 104 columns]

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Shape of Data

# %%
fifa.shape
# Out:
# (18278, 104)

# %% [markdown]
# ## All the columns in the Dataset

# %%
for col in fifa.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %% [markdown]
# ## Players count from different Nationalities

# %%
fifa.nationality.value_counts()[:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x = fifa.nationality.value_counts()[:15].index,
    y = fifa.nationality.value_counts()[:15],
)
plt.xlabel("Nationality")
plt.ylabel("Count Of Players")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Most Paid Players

# %%
player_salary = fifa[["short_name", "wage_eur"]].sort_values(by="wage_eur", ascending=False).reset_index(drop=True)
player_salary[:10]
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1          E. Hazard    470000
# 2  Cristiano Ronaldo    405000
# 3       K. De Bruyne    370000
# 4       A. Griezmann    370000
# 5          L. Suárez    355000
# 6          L. Modrić    340000
# 7           T. Kroos    330000
# 8          S. Agüero    300000
# 9    Sergio Busquets    300000

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x = "short_name",
    y = "wage_eur",
    data = player_salary[:15]
)
plt.xlabel("Player's Short Name")
plt.ylabel("Salary in Euro")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Data of all players from Germany

# %%
Germany = fifa[fifa.nationality == "Germany"]
Germany.head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...  ...   NaN   NaN
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...  ...  55+3  64+3
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...  ...  84+3  78+3
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Data of top 5 tallest players from Germany

# %%
Germany.sort_values(by="height_cm", ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...  ...  43+2  44+2
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...  ...  47+2  39+2
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Top 5 most heaviest players from Germany

# %%
Germany.sort_values(by="weight_kg", ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...  ...  83+2  75+2
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Top 5 most paid players from Germany

# %%
Germany.sort_values(by="wage_eur", ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...  ...  52+2  61+2
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...  ...  72+3  74+3
# 70      189596  https://sofifa.com/player/189596/thomas-muller...  ...  62+3  67+3
#
# [5 rows x 104 columns]

# %%
Germany[["short_name", "wage_eur"]].sort_values(by="wage_eur", ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %% [markdown]
# ## Sorting Players by their Shooting Skills
# #### Top 10 Players with best Shooting Skills

# %%
fifa[["short_name", "nationality", "club", "shooting"]].sort_values(by="shooting", ascending=False).head(10)
# Out:
#             short_name nationality               club  shooting
# 1    Cristiano Ronaldo    Portugal           Juventus      93.0
# 0             L. Messi   Argentina       FC Barcelona      92.0
# 12             H. Kane     England  Tottenham Hotspur      91.0
# 17           S. Agüero   Argentina    Manchester City      90.0
# 205    F. Quagliarella       Italy          Sampdoria      89.0
# 19           L. Suárez     Uruguay       FC Barcelona      89.0
# 96      Z. Ibrahimović      Sweden          LA Galaxy      88.0
# 37             M. Reus     Germany  Borussia Dortmund      88.0
# 100            G. Bale       Wales        Real Madrid      87.0
# 20      R. Lewandowski      Poland  FC Bayern München      87.0

# %% [markdown]
# ## Sorting Players by their Defending Skills
# #### Top 10 Players with best Defending Skills

# %%
fifa[["short_name", "nationality", "club", "defending"]].sort_values(by="defending", ascending=False).head(10)
# Out:
#          short_name  nationality               club  defending
# 16     G. Chiellini        Italy           Juventus       90.0
# 7       V. van Dijk  Netherlands          Liverpool       90.0
# 11     K. Koulibaly      Senegal             Napoli       89.0
# 35         D. Godín      Uruguay              Inter       89.0
# 49       M. Hummels      Germany  Borussia Dortmund       89.0
# 29            Piqué        Spain       FC Barcelona       88.0
# 50  T. Alderweireld      Belgium  Tottenham Hotspur       88.0
# 40       A. Laporte       France    Manchester City       88.0
# 47    J. Vertonghen      Belgium  Tottenham Hotspur       87.0
# 67       L. Bonucci        Italy           Juventus       87.0

# %% [markdown]
# ## Sorting Players of Real Madrid Club by Wages

# %%
read_madrid = fifa[fifa.club == "Real Madrid"]
read_madrid.sort_values(by="wage_eur", ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 46     165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Sorting Players of Real Madrid Club by Shooting Skills

# %%
read_madrid.sort_values(by="shooting", ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...  ...  66+3  70+3
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...  ...  57+3  62+3
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 46      165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...  ...  47+2  51+2
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Sorting Players of Real Madrid Club by Defending Skills

# %%
read_madrid.sort_values(by="defending", ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...  ...  84+3  79+3
# 76      201535  https://sofifa.com/player/201535/raphael-varan...  ...  83+3  77+3
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...  ...  80+3  83+3
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...  ...  79+2  78+2
#
# [5 rows x 104 columns]

# %% [markdown]
# ## Nationality of Players Playing in Real Madrid

# %%
read_madrid.nationality.value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Japan                  1
# Colombia               1
# Wales                  1
# Dominican Republic     1
# Serbia                 1
# Croatia                1
# Uruguay                1
# Costa Rica             1
# Germany                1
# Name: nationality, dtype: int64
